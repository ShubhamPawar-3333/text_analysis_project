# %% [markdown]
# Importing Important libraries

# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob import TextBlob
import spacy
from collections import defaultdict
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Creating Dataframe by Reading CSV file

# %%
data = pd.read_csv("articles.csv", encoding='latin-1')
data.head()
# Out:
#                                              Article  \
# 0  Data analysis is the process of inspecting and...
# 1  The performance of a machine learning algorith...
# 2  You must have seen the news divided into categ...
# 3  When there are only two classes in a classific...
# 4  The Multinomial Naive Bayes is one of the vari...
#
#                                                Title
# 0                  Best Books to Learn Data Analysis
# 1         Assumptions of Machine Learning Algorithms
# 2          News Classification with Machine Learning
# 3  Multiclass Classification Algorithms in Machin...
# 4        Multinomial Naive Bayes in Machine Learning

# %% [markdown]
# Creating word clouds to visualize the most frequent words in the titles.

# %%
# Combining all the titles into single string
titles_text = ' '.join(data['Title'])

# %%
# Creating a wordcloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(titles_text)

# %%
# Plotting the wordcloud
fig = px.imshow(wordcloud, title='Word Cloud of Titles')
fig.update_layout(showlegend=False)
fig.show()

# %% [markdown]
# #### Sentiment Analysis

# %% [markdown]
# Analyzing the sentiment expressed in the articles to understand the overall tone or sentiment of the content

# %%
#Create two new columns ‘Subjectivity’ & ‘Polarity’
data['Subjectivity'] = data['Article'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
data['Polarity'] = data['Article'].apply(lambda x: TextBlob(x).sentiment.polarity)
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
data['Sentiment'] = data['Polarity'].apply(getAnalysis)
data
# Out:
#                                               Article  \
# 0   Data analysis is the process of inspecting and...
# 1   The performance of a machine learning algorith...
# 2   You must have seen the news divided into categ...
# 3   When there are only two classes in a classific...
# 4   The Multinomial Naive Bayes is one of the vari...
# 5   You must have seen the news divided into categ...
# 6   Natural language processing or NLP is a subfie...
# 7   By using a third-party application or API to m...
# 8   Twitter is one of the most popular social medi...
# 9   The squid game is currently one of the most tr...
# 10  Computer Vision is one of the fields of Artifi...
# 11  Python is one of the most popular programming ...
# 12  API stands for Application Programming Interfa...
# 13  A voice recorder is found in every smartphone ...
# 14  Language detection is a natural language proce...
# 15  A Multilayer Perceptron or MLP is one of the s...
# 16  A neural network is a subset of machine learni...
# 17  Clustering is the task of identifying similar ...
# 18  Dictionaries are one of the most useful data s...
# 19  Health Insurance is a type of insurance that c...
# 20  The mean shift algorithm is a nonparametric cl...
# 21  The BIRCH is a Clustering algorithm in machine...
# 22  Agglomerative clustering is based on hierarchi...
# 23  DBSCAN stands for Density-Based Spatial Cluste...
# 24  The K-Means Clustering is a clustering algorit...
# 25  A scatter plot is one of the most useful ways ...
# 26  Recently, we have seen an increase of more tha...
# 27  Apple has just announced the date of its Septe...
# 28  Deep learning is a subset of machine learning ...
# 29  Many machine learning algorithms can be used t...
# 30  Almost every app or website you visit today sh...
# 31  There are so many algorithms in machine learni...
# 32  In machine learning, the Naive Bayes algorithm...
# 33  Swapping elements of a Python list is very sim...
#
#                                                 Title  Subjectivity  Polarity  \
# 0                   Best Books to Learn Data Analysis      0.358333  0.666667
# 1          Assumptions of Machine Learning Algorithms      0.354167  0.020833
# 2           News Classification with Machine Learning      0.900000  0.600000
# 3   Multiclass Classification Algorithms in Machin...      0.525000  0.625000
# 4         Multinomial Naive Bayes in Machine Learning      0.771429 -0.101429
# 5           News Classification with Machine Learning      0.900000  0.600000
# 6                             Best Books to Learn NLP      0.500000  0.283333
# 7                Send Instagram Messages using Python      0.200000  0.050000
# 8      Pfizer Vaccine Sentiment Analysis using Python      0.553333  0.406667
# 9          Squid Game Sentiment Analysis using Python      0.383333 -0.108333
# 10                Best Books to Learn Computer Vision      0.346875  0.346875
# 11                     Best Resources to Learn Python      0.565000  0.580000
# 12               Best Python Frameworks to Build APIs      0.388690  0.479167
# 13                        Voice Recorder using Python      0.262500  0.200000
# 14           Language Detection with Machine Learning      0.483333  0.016667
# 15          Multilayer Perceptron in Machine Learning      0.000000  0.000000
# 16                           Types of Neural Networks      0.250000 -0.075000
# 17          Clustering Algorithms in Machine Learning      0.400000  0.000000
# 18  For Loop Over Keys and Values in a Python Dict...      0.616667  0.150000
# 19  Health Insurance Premium Prediction with Machi...      0.166667  0.083333
# 20          Mean Shift Clustering in Machine Learning      0.515625 -0.234375
# 21               BIRCH Clustering in Machine Learning      0.000000  0.000000
# 22       Agglomerative Clustering in Machine Learning      0.342308  0.157692
# 23              DBSCAN Clustering in Machine Learning      1.000000 -0.800000
# 24             K-Means Clustering in Machine Learning      0.343333  0.091111
# 25                 Animated Scatter Plot using Python      0.250000  0.400000
# 26  Tata Motors Stock Price Prediction with Machin...      0.412500  0.175000
# 27  Apple Stock Price Prediction with Machine Lear...      0.584848  0.245455
# 28                  Best Books to Learn Deep Learning      0.440357  0.118929
# 29                      Applications of Deep Learning      0.422449  0.089796
# 30             Introduction to Recommendation Systems      0.460000  0.270000
# 31  Use Cases of Different Machine Learning Algori...      0.750000  0.288571
# 32          Naive Bayes Algorithm in Machine Learning      0.625000 -0.181250
# 33                        Swap Items of a Python List      0.520000  0.000000
#
#     Analysis Sentiment
# 0   Positive  Positive
# 1   Positive  Positive
# 2   Positive  Positive
# 3   Positive  Positive
# 4   Negative  Negative
# 5   Positive  Positive
# 6   Positive  Positive
# 7   Positive  Positive
# 8   Positive  Positive
# 9   Negative  Negative
# 10  Positive  Positive
# 11  Positive  Positive
# 12  Positive  Positive
# 13  Positive  Positive
# 14  Positive  Positive
# 15   Neutral   Neutral
# 16  Negative  Negative
# 17   Neutral   Neutral
# 18  Positive  Positive
# 19  Positive  Positive
# 20  Negative  Negative
# 21   Neutral   Neutral
# 22  Positive  Positive
# 23  Negative  Negative
# 24  Positive  Positive
# 25  Positive  Positive
# 26  Positive  Positive
# 27  Positive  Positive
# 28  Positive  Positive
# 29  Positive  Positive
# 30  Positive  Positive
# 31  Positive  Positive
# 32  Negative  Negative
# 33   Neutral   Neutral

# %% [markdown]
# Subjectivity quantifies the amount of personal opinion and factual information contained in the text. The higher subjectivity means that the text contains personal opinion rather than factual information. Polarity implies Positive, Negative or Neutral Sentiments

# %%
fig1 = px.histogram(data, x='Subjectivity', title='Subjectivity Distribution', histfunc='count', text_auto=True)
fig2 = px.histogram(data, x='Polarity', title='polarity Distribution')
fig3 = px.histogram(data, x='Sentiment', title='Complete Analysis', histfunc='count', text_auto=True)
fig1.show()
fig2.show()
fig3.show()

# %% [markdown]
# From above analysis it can be observed that most of the articles have Positive polarity. Whereas majority of articles have factual information.

# %% [markdown]
# #### Named Entity Recognition

# %%
text = data['Article'][0]
text
# Out:
# 'Data analysis is the process of inspecting and exploring data generated by a particular population to find the information needed to make decisions and draw conclusions. With the use of data in decision making, most businesses today need data analysts. So, if you want to know about the best books to learn data analysis, this article is for you. In this article, I will introduce you to some of the best books to learn data analysis.'

# %%
doc = nlp(text)

# %%
sentence = list(doc.sents)
sentence
# Out:
# [Data analysis is the process of inspecting and exploring data generated by a particular population to find the information needed to make decisions and draw conclusions.,
#  With the use of data in decision making, most businesses today need data analysts.,
#  So, if you want to know about the best books to learn data analysis, this article is for you.,
#  In this article, I will introduce you to some of the best books to learn data analysis.]

# %%
for token in doc:
    print(token.text)
# Out:
# Data
# analysis
# is
# the
# process
# of
# inspecting
# and
# exploring
# data
# generated
# by
# a
# particular
# population
# to
# find
# the
# information
# needed
# to
# make
# decisions
# and
# draw
# conclusions
# .
# With
# the
# use
# of
# data
# in
# decision
# making
# ,
# most
# businesses
# today
# need
# data
# analysts
# .
# So
# ,
# if
# you
# want
# to
# know
# about
# the
# best
# books
# to
# learn
# data
# analysis
# ,
# this
# article
# is
# for
# you
# .
# In
# this
# article
# ,
# I
# will
# introduce
# you
# to
# some
# of
# the
# best
# books
# to
# learn
# data
# analysis
# .

# %%
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)
# Out:
# [('today', 227, 232, 'DATE')]

# %%
def extract_named_entities(text):
    doc = nlp(text)
    entities = defaultdict(list)
    for ent in doc.ents:
        entities[ent.label_].append(ent.text)
    return dict(entities)

data['Named_Entities'] = data['Article'].apply(extract_named_entities)

# %%
data['Named_Entities']
# Out:
# 0                                   {'DATE': ['today']}
# 1                                                    {}
# 2                                                    {}
# 3           {'CARDINAL': ['only two', 'more than two']}
# 4     {'ORG': ['The Multinomial Naive Bayes', 'Naive...
# 5                                                    {}
# 6     {'ORG': ['NLP', 'NLP', 'NLP', 'NLP'], 'CARDINA...
# 7     {'ORDINAL': ['third'], 'ORG': ['API', 'Instagr...
# 8     {'PRODUCT': ['Twitter', 'Twitter'], 'CARDINAL'...
# 9             {'ORG': ['NetFlix'], 'CARDINAL': ['One']}
# 10    {'ORG': ['Computer Vision', 'Artificial Intell...
# 11    {'DATE': ['today', 'today'], 'ORG': ['Google',...
# 12    {'ORG': ['API', 'Application Programming Inter...
# 13                                  {'DATE': ['today']}
# 14                        {'DATE': ['a few years ago']}
# 15    {'ORG': ['Multilayer Perceptron', 'Multilayer ...
# 16                          {'ORG': ['Data Scientist']}
# 17                                                   {}
# 18                                {'CARDINAL': ['one']}
# 19                        {'ORG': ['Health Insurance']}
# 20                        {'ORG': ['Machine Learning']}
# 21    {'ORG': ['Clustering', 'Balanced Reducing and ...
# 22                             {'ORG': ['the K-Means']}
# 23    {'ORG': ['DBSCAN', 'Density-Based Spatial Clus...
# 24    {'ORG': ['The K-Means Clustering', 'the K-Mean...
# 25                                {'CARDINAL': ['two']}
# 26    {'CARDINAL': ['more than 10'], 'ORG': ['Tata M...
# 27    {'ORG': ['Apple', 'Apple', 'Apple'], 'DATE': [...
# 28                                                   {}
# 29                                                   {}
# 30    {'DATE': ['today'], 'ORG': ['YouTube', 'YouTub...
# 31                                                   {}
# 32    {'ORG': ['Naive Bayes', 'Bayes', 'Naive Bayes'...
# 33                        {'GPE': ['Python', 'Python']}
# Name: Named_Entities, dtype: object

# %%
entity_counts = Counter(entity for entities in data['Named_Entities'] for entity in entities)
entity_df = pd.DataFrame.from_dict(entity_counts, orient='index').reset_index()
entity_df.columns = ['Entity', 'Count']

# %%
fig = px.bar(entity_df.head(10), x='Entity', y='Count', title='Top 10 Named Entities')
fig.show()

# %%
vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=1000, stop_words='english')
tf = vectorizer.fit_transform(data['Article'])
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)
lda_topic_matrix = lda_model.fit_transform(tf)

# %%
topic_names = ["Topic " + str(i) for i in range(lda_model.n_components)]
topic_names

# %%
data['Dominant_Topic'] = [topic_names[i] for i in lda_topic_matrix.argmax(axis=1)]

# %%
data['Dominant_Topic'].value_counts()

# %%
data['Dominant_Topic'].value_counts().reset_index()

# %%
fig = px.bar(data['Dominant_Topic'].value_counts().reset_index(), x='Dominant_Topic', y='count', title='Topic Distribution')
fig.show()
